# %%
# Assignment 1: Calculator Create a simple calculator that: Gets two numbers from user Asks for operation (+, -, *, /) Performs the operation Prints the result
# Assignment 2: Email Parser Get an email address from user and print: The username (before @)
# The domain (after @) Whether it’s a .com, .org, or other
#Assignment 3: Mad Libs Create a mad libs game: Ask for: noun, verb, adjective, 
# place Create a funny story using their inputs

# %%
print("1- Add")
print("2- Subtract")
print("3- Multiply")
print("4- Divide")
option=int(input('Choose an operation:'))

if(option in [1,2,3,4]):
    num1=float(input('Enter first number:'))
    num2=float(input('Enter second number:'))
    
    if(option==1):
        result=num1+num2
    elif(option==2):
        result=num1-num2
    elif(option==3):
        result=num1*num2
    elif(option==4):
        result=num1/num2
else:
    print('Invalid Operation Entered')
print('Result of operation is {}'.format(result))
# Out:
# 1- Add
# 2- Subtract
# 3- Multiply
# 4- Divide
# Choose an operation: 4
# Enter first number: 7
# Enter second number: 2
# Result of operation is 3.5

# %%
## Shuffle deck of cards

# %%
import itertools
import random

Deck= list(itertools.product(range(1,14),['spades','diamonds','hearts','clubs']))

random.shuffle(Deck)

for i in range(5):
    print(Deck[i][0], 'of' ,Deck[i][1])
# Out:
# 3 of hearts
# 2 of hearts
# 5 of diamonds
# 8 of diamonds
# 7 of hearts

# %%
# Email paser
email=input('your email')

# %%
school=str(input('Please enter a school'))
noun=str(input('Please enter a noun'))
verb=str(input('Please enter a verb'))
adjective=str(input('Please enter an adjective'))
print ( noun, "walked home from", school, "after",verb,adjective, "-")

print(noun,'is',verb,'to become a' ,adjective,'Data analyst','from',school)
# Out:
# Please enter a school Lux Dev
# Please enter a noun Faith
# Please enter a verb studying
# Please enter an adjective diligent
# Faith walked home from Lux Dev after studying diligent -
# Faith is studying to become a diligent Data analyst -

# %%
# Email Parser

email = input("Enter your email address: ")

if "@" in email:

    username, domain = email.split("@")

    print("Username:", username)
    print("Domain:", domain)

    if domain.endswith(".com"):
        print("Type: .com")

    elif domain.endswith(".org"):
        print("Type: .org")

    else:
        print("Type: Other")

else:
    print("Invalid email address")
# Out:
# Enter your email address:  faithc@gmail.com
# Username: faithc
# Domain: gmail.com
# Type: .com
